# %% [markdown]
# # C11 get C11 voter data
#
# For the city-only data, I hand'cleaned the file.
# * I removed these partial cities: Boonton NJ (34027066, Chatham NJ (34027121, Mendham NJ (34027453, Rockaway NJ (34027640
#
# I cleaned up placenames (all corrections were done in the voter data preprocessing so we could reuse the C11 lists): these places were in the C11 list, but not on the list of towns in the votes file:
# * ESSEX: totally clean
# * MORRIS: Missing Hanover, Jefferson, Morris, Victory Gardens.  No idea why; will look for them later.
# * PASSAIC: totally clean
# * SUSSEX: Missing Byram.  No idea why; will look for it later.
#
# Totals for all parties: 506961
# * Found 199255 people in Essex
# * Found 187874 people in Morris
# * Found 88037 people in Passaic
# * Found 31795 people in Sussex
#
# Totals for just DEMs: 160993
# * Found 83302 people in Essex
# * Found 47634 people in Morris
# * Found 23301 people in Passaic
# * Found 6756 people in Sussex

# %%
import pandas as pd
import csv
import zipfile
import os
import glob
import csv 
import math
import njvotes
pd.set_option("display.max_columns", 999)


# Get data headers
nametypes = njvotes.get_voteheadertypes()

# %%
# Set these flags to change what comes out.  
parties = 'DEM' # Parties = "DEM" gives only democrats; ditto "REP" for republicans
areas = 'town' # Areas=town gives only towns (that's the only option at the moment)
phones = '10digit' # Set to 'all' if you want all phone numbers; 10 if you want only 10digit ones

# Create master list of name, phone number, county for this one district
dfcities = pd.read_csv('../2017 Other data/ncjd-2011-district11cities-handcleaned.csv')
dfcities['City'] = dfcities['City'].str.title().str.strip()

allvoters = pd.DataFrame([])
for county in dfcities['County'].unique():
    
    # Get voting data from file
    print('Getting voter data for {}'.format(county))
    df = pd.read_csv('../2017 Voting data/'+county.upper()+'/ElectionHistory_cleaned.csv', 
                     dtype=nametypes)
    df = df.fillna('')
    df['county'] = county.title()

    # Only keep data for the cities we're interested in
    getcities = dfcities[dfcities['County'] == county]['City'].unique().tolist()
    df = df[df['city'].isin(getcities)]
    print('{}. Looking for these cities: {}\nFound: {}'.format(county, getcities, df['city'].unique()))
    
    # Only keep one record per voter (we don't care about how they voted at this point)
    df.drop_duplicates(subset='voter id', inplace=True, keep='last')
    print('{} Found {} people'.format(county, len(df)))

    # Do any asked-for filtering
    if parties != 'all':
        df = df[df['party code'] == parties]

    if phones == '10digit':
        df.loc[df['phone number'].str.len() < 10, ['phone number']] = ''
    
    # Format and add to stack
    df = njvotes.format_for_nationbuilder(df)
    allvoters = allvoters.append(df)

outfile = '../2017 voter data/C11voters_{}parties_{}area_{}phone.csv'.format(parties, areas, phones)
allvoters.to_csv(outfile, index=False)
# Out:
# Getting voter data for Essex
# Essex. Looking for these cities: ['Bloomfield', 'Caldwell', 'Cedar Grove', 'Essex Fells', 'Fairfield', 'Livingston', 'Montclair', 'North Caldwell', 'Nutley', 'Roseland', 'Verona', 'West Caldwell', 'West Orange']
# Found: ['Bloomfield' 'Caldwell' 'Cedar Grove' 'Essex Fells' 'Fairfield'
#  'Livingston' 'Montclair' 'North Caldwell' 'Nutley' 'Roseland' 'Verona'
#  'West Caldwell' 'West Orange']
# Essex Found 199256 people
# Getting voter data for Morris
# Morris. Looking for these cities: ['Boonton', 'Butler', 'Chatham', 'Denville', 'East Hanover', 'Florham Park', 'Hanover', 'Harding', 'Jefferson', 'Kinnelon', 'Lincoln Park', 'Madison', 'Mendham', 'Montville', 'Morris', 'Morris Plains', 'Morristown', 'Mountain Lakes', 'Parsippany-Troy Hills', 'Pequannock', 'Randolph', 'Riverdale', 'Rockaway', 'Victory Gardens']
# Found: ['Boonton' 'Denville' 'Butler' 'Kinnelon' 'Chatham' 'Morristown' 'Madison'
#  'Randolph' 'Mendham' 'Rockaway' 'Mountain Lakes' 'Morris Plains'
#  'East Hanover' 'Florham Park' 'Harding' 'Lincoln Park' 'Montville'
#  'Parsippany-Troy Hills' 'Pequannock' 'Riverdale']
# Morris Found 187875 people
# Getting voter data for Passaic
# Passaic. Looking for these cities: ['Bloomingdale', 'Little Falls', 'North Haledon', 'Pompton Lakes', 'Totowa', 'Wanaque', 'Wayne', 'Woodland Park']
# Found: ['Bloomingdale' 'Wanaque' 'Little Falls' 'North Haledon' 'Pompton Lakes'
#  'Totowa' 'Wayne' 'Woodland Park']
# Passaic Found 88038 people
# Getting voter data for Sussex
# Sussex. Looking for these cities: ['Byram', 'Hopatcong', 'Ogdensburg', 'Sparta', 'Stanhope']
# Found: ['Stanhope' 'Sparta' 'Ogdensburg' 'Hopatcong']
# Sussex Found 31796 people

# %% [markdown]
# # Code used to check and clean for code above

# %%
dfcities = pd.read_csv('../2017 Other data/ncjd-2011-district11cities-handcleaned.csv')
counties = dfcities['County'].unique()
print('All counties in C11: {}'.format(counties))

for county in counties:
    
    # Show data for this county
    print('{}'.format(dfcities[dfcities['County'].isin([county])]))
    
    # Get list of towns in C11 for this county
    c11towns = dfcities[dfcities['County'] == 'Sussex']['City'].unique().tolist()
    print('{} towns in C11: {}'.format(county, c11towns))
    
    # Get list of towns in this dataset
    dfcounty = pd.read_csv('../2017 Voting data/'+county.upper()+'/ElectionHistory_cleaned.csv', 
                           dtype=nametypes)
    towns = dfcounty['city'].astype(str).unique().tolist()
    towns.sort()
    print('{} towns in voting data: {}'.format(county, towns))
# Out:
# All counties in C11: ['Essex' 'Morris' 'Passaic' 'Sussex']
#     District County             City  Population
# 0         11  Essex       Bloomfield       22835
# 1         11  Essex         Caldwell        7822
# 2         11  Essex      Cedar Grove       12411
# 3         11  Essex      Essex Fells        2113
# 4         11  Essex        Fairfield        7466
# 5         11  Essex       Livingston       29366
# 6         11  Essex        Montclair       11299
# 7         11  Essex   North Caldwell        6183
# 8         11  Essex           Nutley       28370
# 9         11  Essex         Roseland        5819
# 10        11  Essex           Verona       13332
# 11        11  Essex    West Caldwell       10759
# 12        11  Essex      West Orange       28085
# Essex towns in C11: [' Byram', ' Hopatcong', ' Ogdensburg', ' Sparta', ' Stanhope']
# Essex towns in voting data: ['Avenel', 'Belleville', 'Bloomfield', 'Caldwell', 'Cedar Grove', 'Clark', 'Columbia', 'Denville', 'East Orange', 'Eatontown', 'Elizabeth', 'Englewood', 'Essex Fells', 'Fairfield', 'Glen Ridge', 'Hackensack', 'Irvington', 'Jersey City', 'Keasbey', 'Leonardo', 'Linden', 'Livingston', 'Maplewood', 'Millburn', 'Montclair', 'Newark', 'North Caldwell', 'Nutley', 'Orange', 'Paterson', 'Roseland', 'Roselle Park', 'Secaucus', 'South Orange', 'Springfield', 'Verona', 'Weehawken', 'West Caldwell', 'West Long Branch', 'West Orange', 'Woodbridge', 'nan']
#     District  County                    City  Population
# 13        11  Morris                 Boonton        4263
# 14        11  Morris                  Butler        7539
# 15        11  Morris                 Chatham       10452
# 16        11  Morris                Denville       16635
# 17        11  Morris            East Hanover       11157
# 18        11  Morris            Florham Park       11696
# 19        11  Morris                 Hanover       13712
# 20        11  Morris                 Harding        3838
# 21        11  Morris               Jefferson       21314
# 22        11  Morris                Kinnelon       10248
# 23        11  Morris            Lincoln Park       10521
# 24        11  Morris                 Madison       15845
# 25        11  Morris                 Mendham        4981
# 26        11  Morris               Montville       21528
# 27        11  Morris                  Morris       22306
# 28        11  Morris           Morris Plains        5532
# 29        11  Morris              Morristown       18411
# 30        11  Morris          Mountain Lakes        4160
# 31        11  Morris   Parsippany-Troy Hills       53238
# 32        11  Morris              Pequannock       15540
# 33        11  Morris                Randolph       25734
# 34        11  Morris               Riverdale        3559
# 35        11  Morris                Rockaway        6438
# 36        11  Morris         Victory Gardens        1520
# Morris towns in C11: [' Byram', ' Hopatcong', ' Ogdensburg', ' Sparta', ' Stanhope']
# Morris towns in voting data: ['Annandale', 'Basking Ridge', 'Belford', 'Berkeley Heights', 'Bernardsville', 'Boonton', 'Boonton Township', 'Brookside', 'Budd Lake', 'Butler', 'Califon', 'Cedar Knolls', 'Chatham', 'Chester', 'Convent Station', 'Denville', 'Dover', 'East Hanover', 'Eatontown', 'Far Hills', 'Flanders', 'Flemington', 'Florham Park', 'Gillette', 'Gladstone', 'Glen Gardner', 'Green Village', 'Hackettstown', 'Harding', 'Hibernia', 'Ironia', 'Kenvil', 'Kinnelon', 'Kinnelon Ugh', 'Lake Hiawatha', 'Lake Hopatcong', 'Landing', 'Ledgewood', 'Lincoln Park', 'Long Valley', 'Madison', 'Manalapan', 'Mendham', 'Mendham Township', 'Millington', 'Mine Hill', 'Montville', 'Morris Plains', 'Morristown', 'Mount Arlington', 'Mount Tabor', 'Mountain Lakes', 'Netcong', 'New Vernon', 'Newark', 'Newfoundland', 'Oak Ridge', 'Parsippany', 'Parsippany-Troy Hills', 'Paterson', 'Pequannock', 'Pine Brook', 'Pompton Plains', 'Port Murray', 'Port Norris', 'Randolph', 'Riverdale', 'Rockaway', 'Roselle Park', 'Schooleys Mountain', 'Secaucus', 'Stanhope', 'Stirling', 'Stockholm', 'Succasunna', 'Towaco', 'Weehawken', 'Wharton', 'Whippany']
#     District   County            City  Population
# 37        11  Passaic    Bloomingdale        7656
# 38        11  Passaic    Little Falls       14432
# 39        11  Passaic   North Haledon        8417
# 40        11  Passaic   Pompton Lakes       11097
# 41        11  Passaic          Totowa       10804
# 42        11  Passaic         Wanaque       11116
# 43        11  Passaic           Wayne       54717
# 44        11  Passaic   Woodland Park       11819
# Passaic towns in C11: [' Byram', ' Hopatcong', ' Ogdensburg', ' Sparta', ' Stanhope']
# Passaic towns in voting data: ['Bloomingdale', 'Cedar Grove', 'Clark', 'Clifton', 'Englewood', 'Haledon', 'Haskell', 'Hawthorne', 'Hewitt', 'Jersey City', 'Kampfe Lake', 'Lake Iosco Haskell', 'Little Falls', 'Montclair', 'Newfoundland', 'North Caldwell', 'North Haledon', 'Nutley', 'Oak Ridge', 'Oakland', 'Ocean', 'Passaic', 'Paterson', 'Pompton Lakes', 'Prospect Park', 'Ringwood', 'Roselle Park', 'Secaucus', 'Stockholm', 'Totowa', 'Upper Montclair', 'Ventnor City', 'Wanaque', 'Wayne', 'West Milford', 'Woodland Park', 'nan']
#     District  County         City  Population
# 45        11  Sussex        Byram        8350
# 46        11  Sussex    Hopatcong       15147
# 47        11  Sussex   Ogdensburg        2410
# 48        11  Sussex       Sparta       19722
# 49        11  Sussex     Stanhope        3610
# Sussex towns in C11: [' Byram', ' Hopatcong', ' Ogdensburg', ' Sparta', ' Stanhope']
# Sussex towns in voting data: ['Andover', 'Augusta', 'Blairstown', 'Branchville', 'Budd Lake', 'Califon', 'Clark', 'Columbia', 'Englewood', 'Franklin', 'Glasser', 'Glenwood', 'Hamburg', 'Hardyston', 'Hewitt', 'Highland Lakes', 'Hopatcong', 'Lafayette', 'Lake Hopatcong', 'Layton', 'Mcafee', 'Montague', 'Newton', 'Ogdensburg', 'Sandyston', 'Secaucus', 'Sparta', 'Stanhope', 'Stockholm', 'Sussex', 'Vernon', 'Walpack', 'Wantage', 'Warwick Ny']

# %%
df2 = pd.read_csv('../2017 Voting data/MORRIS/ElectionHistory_cleaned.csv', dtype=nametypes)
print('{}'.format(df2.columns))
df2.head()
# Out:
# Index(['voter id', 'status code', 'party code', 'last name', 'first name',
#        'middle name', 'prefix', 'suffix', 'sex', 'street number', 'suffix a',
#        'suffix b', 'street name', 'apt/unit no.', 'address line 1',
#        'address line 2', 'city', 'state', 'zip5', 'zip4',
#        'mailing street number', 'mailing suffix a', 'mailing suffix b',
#        'mailing street name', 'mailing apt/unit no.', 'mailing address line 1',
#        'mailing address line 2', 'mailing city', 'mailing state',
#        'mailing country', 'mailing zip code', 'birth date', 'date registered',
#        'county precinct', 'municipality', 'ward', 'district', 'phone number',
#        'election date', 'election name', 'election type', 'election category',
#        'ballot type'],
#       dtype='object')
#     voter id status code party code last name first name middle name prefix  \
# 0  116002492           A        REP    Afonso     Angela         NaN    NaN
# 1  116002492           A        REP    Afonso     Angela         NaN    NaN
# 2  116002492           A        REP    Afonso     Angela         NaN    NaN
# 3  116002492           A        REP    Afonso     Angela         NaN    NaN
# 4  116002492           A        REP    Afonso     Angela         NaN    NaN
#
#   suffix sex street number suffix a suffix b street name apt/unit no.  \
# 0    NaN   N             3      NaN      NaN     Park Rd          NaN
# 1    NaN   N             3      NaN      NaN     Park Rd          NaN
# 2    NaN   N             3      NaN      NaN     Park Rd          NaN
# 3    NaN   N             3      NaN      NaN     Park Rd          NaN
# 4    NaN   N             3      NaN      NaN     Park Rd          NaN
#
#   address line 1 address line 2              city state   zip5 zip4  \
# 0            NaN            NaN  Boonton Township    NJ  07005  NaN
# 1            NaN            NaN  Boonton Township    NJ  07005  NaN
# 2            NaN            NaN  Boonton Township    NJ  07005  NaN
# 3            NaN            NaN  Boonton Township    NJ  07005  NaN
# 4            NaN            NaN  Boonton Township    NJ  07005  NaN
#
#   mailing street number mailing suffix a mailing suffix b mailing street name  \
# 0                   NaN              NaN              NaN                 NaN
# 1                   NaN              NaN              NaN                 NaN
# 2                   NaN              NaN              NaN                 NaN
# 3                   NaN              NaN              NaN                 NaN
# 4                   NaN              NaN              NaN                 NaN
#
#   mailing apt/unit no. mailing address line 1 mailing address line 2  \
# 0                  NaN                    NaN                    NaN
# 1                  NaN                    NaN                    NaN
# 2                  NaN                    NaN                    NaN
# 3                  NaN                    NaN                    NaN
# 4                  NaN                    NaN                    NaN
#
#   mailing city mailing state mailing country mailing zip code  birth date  \
# 0          NaN           NaN             NaN              NaN  04/22/1964
# 1          NaN           NaN             NaN              NaN  04/22/1964
# 2          NaN           NaN             NaN              NaN  04/22/1964
# 3          NaN           NaN             NaN              NaN  04/22/1964
# 4          NaN           NaN             NaN              NaN  04/22/1964
#
#   date registered county precinct      municipality ward district  \
# 0      08/10/2004        11600040  Boonton Township   00       01
# 1      08/10/2004        11600040  Boonton Township   00       01
# 2      08/10/2004        11600040  Boonton Township   00       01
# 3      08/10/2004        11600040  Boonton Township   00       01
# 4      08/10/2004        11600040  Boonton Township   00       01
#
#   phone number election date           election name election type  \
# 0   9733165874    11/06/2007  State-General Election           GEN
# 1   9733165874    11/04/2008        General Election           GEN
# 2   9733165874    04/15/2008   State-School Election           ANS
# 3   9733165874    11/03/2009  State General Election           GEN
# 4   9733165874    04/20/2010   State-School Election           ANS
#
#   election category ballot type
# 0                 S           M
# 1                 S           M
# 2                 S           M
# 3                 S           M
# 4                 S           M
