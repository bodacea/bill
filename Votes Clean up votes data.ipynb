# %% [markdown]
# # Votes: Clean voting data
#
# Basic cleaning:
# * Add a header row
# * Comma-separate (not this stupid pipe crap)
# * Capitalise all names and address fields (Street name, city)
#
# Column-specific cleaning:
# * Clean up dirt in the voting column "city"
# * If street name is numeric, then swap apt and street name (affects 27000 people in ESSEX)
# * If apt/unit no. is filled and street name is empty, put apt/unit no. contents into street name
# * Many birthdates are 01/01/1800 (1200 of these in Essex0); some are 01/01/1111, 12/31/1899.  Some are blank.  Turned all the nonvalid birthdates (including blanks) into 01/01/1800.
#
# Notes and remaining issues:
# * TODO: Last row in votes file is the number of voters. Removed this, but doesn't match the number of voting ids: check them?
# * TODO: VAN only takes 10-digit phone numbers. Turned everything else into blanks, but will need to think about how to potentially use these other numbers too (e.g. are there dominant local area codes we can use?). Wierd thing of the day is that there's a dominant 3-digit code (732): does this mean something like "do not contact", or "doesn't have phone"?
# * Ignored: IF mailing address is empty, copy over the street address
# * Burlington county: why is Egg Harbor in here?
# * Whole pile of votes in Sussex with city as "sussex" (they're in Wantage etc; think clerk may have been lazy here... )

# %%
# Just run this section!!!

import pandas as pd
import csv
import zipfile
import os
import glob
import csv 
import re
import njvotes
pd.set_option("display.max_columns", 999)


voteheaders = njvotes.get_voteheaders()
voteheadertypes = njvotes.get_voteheadertypes()
citycorrections = njvotes.set_citycorrections()

# Get dataset
for county in citycorrections.keys():
    print('{}'.format(county))
    votedatafile = '../2017 Voting data/' + county + '/ElectionHistory.txt'
    df = pd.read_csv(votedatafile, sep='|', names=voteheaders, dtype=voteheadertypes) 
    # index_col=None, low_memory=False 
    
    # last row in voting file is a comment with number of voters
    df = df[:-1]
    df = df.drop('xx',axis=1)
    df = df.fillna('')

    # Lowercase the city names and clean up all the obvious errors in them
    df['city'] = df['city'].str.lower().str.strip() #Yep, there were spaces at the end of city names...
    for badval, goodval in citycorrections[county].items():
        df['city'] = df['city'].str.replace(badval, goodval)

    # Clean up errors in address columns
    idx = df['street name'] == ''
    df.loc[idx, ['street name', 'apt/unit no.']] = df.loc[idx, ['apt/unit no.', 'street name']].values
    idx = (df['street name'].str.isnumeric())
    df.loc[idx,['street name','apt/unit no.']] = df.loc[idx,['apt/unit no.','street name']].values

    # Titlecase all the names and placenames
    for col in ['last name', 'first name', 'middle name', 'prefix', 'suffix', 'street name', 
               'city', 'election name', 'municipality']:
        df[col] = df[col].str.title().str.strip()

    # Clean up birthdates (so only 01/01/1800 is the missing-data value)
    df.loc[df['birth date']=='01/01/1111', ['birth date']] = '01/01/1800'
    df.loc[df['birth date']=='12/31/1899', ['birth date']] = '01/01/1800'
    df.loc[df['birth date']=='', ['birth date']] = '01/01/1800'   

    # Output
    df.to_csv(votedatafile[:-4]+'_cleaned.csv', index=False)
# Out:
# WARREN
# BURLINGTON
# HUDSON
# MONMOUTH
# MORRIS
# GLOUCESTER
# CAMDEN
# MIDDLESEX
# MERCER
# SUSSEX
# BERGEN
# CAPE MAY
# OCEAN
# ATLANTIC
# UNION
# ESSEX
# SOMERSET
# SALEM
# PASSAIC
# CUMBERLAND
# HUNTERDON

# %% [markdown]
# # All the checks done to create the corrections lists above

# %%
# Get the 'official' list of towns in this county
county = 'WARREN'

def capcase(x):
    return ' '.join([y.capitalize() for y in x.split(' ')])

corrs = citycorrections[county]

# Get official list of NJ towns
alltowns = pd.read_csv('../2017 other data/localnames_nj.txt', sep='\t', 
                       names=['Local Name', 'Municipality', 'County'])
ctowns = alltowns[alltowns['County'] == capcase(county)]
# print('{}'.format(ctowns))

# muns = ctowns['Municipality'].unique()
# muns.sort()
# print('{}'.format(muns))

ctowns['Local Name'].unique()
# Out:
# array(['Allamuchy', 'Allamuchy Township', 'Allens Mills', 'Alpha',
#        'Alphano', 'Anderson', 'Andover Furnace', 'Asbury', 'Bass Lake',
#        'Belvidere', 'Bettystown', 'Blair Lake', 'Blairstown',
#        'Blairstown Township', 'Brainards', 'Brass Castle', 'Bridgeville',
#        'Broadway', 'Browning', 'Buckwood Park', 'Butlers Park',
#        'Buttzville', 'Calno', 'Carpentersville', 'Catfish Pond',
#        'Cedar Lake', 'Changewater', 'Columbia', 'Cooks Pond',
#        'Coopersville', 'Cornish', 'Deckers Ferry', 'Delaware',
#        'Delaware Park', 'Denville', 'Dunnfield', 'Ebenezer ', 'Feebletown',
#        'Finesville', 'Fort Golden', 'Foul Rift', 'Franklin Grove',
#        'Franklin Township', 'Frelinghuysen Township', 'Glovers Pond',
#        'Great Meadows', 'Greenwich Township', 'Hackettstown', 'Hainesburg',
#        'Hardwick', 'Hardwick Center', 'Hardwick Township', 'Harmony',
#        'Harmony Station', 'Harmony Township', 'Hazen', 'Hope',
#        'Hughesville ', 'Huntington', 'Hutchinson', 'Independence Township',
#        'Ingersol Heights', 'Jacksonburg', 'Jenny Jump State Forest',
#        'Johnsonburg', 'Kalaroma', 'Karrsville', 'Kennedys',
#        'Kennedys Mill', 'Kerrs Corners', 'Knowlton', 'Knowlton Township',
#        'Lake Susquehanna', 'Liberty Township', 'Little York',
#        'Locust Lake', 'Long Bridge', 'Lopatcong', 'Lopatcong Heights',
#        'Lower Harmony', 'Mansfield Township', 'Manunka Chunk', 'Marksboro',
#        'Martins Creek Station', 'Millbrook', 'Montana', 'Mount Bethel',
#        'Mount Herman', 'Mount Pleasant', 'Mount Vernon', 'Mountain Lake',
#        'New Village', 'Newbakers Corner', 'Oxford', 'Paulina', 'Penwell',
#        'Pequest', 'Petersburgh', 'Phillipsburg', 'Pleasant Valley',
#        'Pohatcong Township', 'Polkville', 'Port Colden', 'Port Murray',
#        'Port Warren', 'Quaker Church', 'Ramseyburg', 'Riegelsville',
#        'Rockport', 'Roxburg', 'Sand Pond', 'Sarepta', 'Saxton Falls',
#        'Shiloh', 'Shirmers', 'Silver Lake', 'Southtown', 'Springtown',
#        'Squares Corner', 'Stephensburg', 'Stewartsville', 'Still Valley',
#        'Summerfield', 'Sunfish Pond', 'Swayzes Mill', 'Townsbury',
#        'Union Town', 'Vail', 'Vienna', 'Vulcanite', 'Walnut Valley',
#        'Warren', 'Warren Furnace', 'Warren Glen', 'Warren Heights',
#        'Warrenville', 'Warrington', 'Washington', 'Washington Township',
#        'White Pond', 'White Township', 'Willow Grove', 'Yellow Frame'], dtype=object)

# %%
# Get the list of towns found in the voting dataset

votedatafile = '../2017 Voting data/' + county + '/ElectionHistory.txt'
df = pd.read_csv(votedatafile, sep='|', names = voteheaders, 
                index_col=None, low_memory=False, 
                 dtype={'phone number': 'str', 'zip5': 'str', 'zip4': 'str', 
                       'county precinct': 'str'})
df['city'] = df['city'].str.lower()
cits = df['city'].astype(str).unique()
cits.sort()
cits
# Out:
# array(['allamuchy', 'alpha', 'andover', 'asbury', 'belvidere',
#        'blairstown', 'bloomsbury', 'broadway', 'columbia', 'delaware',
#        'great meadows', 'hackettstown', 'hampton', 'hope', 'johnsonburg',
#        'mansfield', 'milford', 'nan', 'newton', 'oxford', 'phillipsburg',
#        'port murray', 'roselle park', 'stanhope', 'stewarsville',
#        'stewartsville', 'stewartville', 'vienna', 'washington'], dtype=object)

# %%
# Go look at data for one of these towns
df[df['city'] =="vienna"]
# Out:
#          voter id status code party code  last name first name middle name  \
# 202350  118074434           A        UNA    BORBONE    DEBORAH           A
# 202351  118074434           A        UNA    BORBONE    DEBORAH           A
# 202352  118074434           A        UNA    BORBONE    DEBORAH           A
# 202353  118074434           A        UNA    BORBONE    DEBORAH           A
# 202354  118074434           A        UNA    BORBONE    DEBORAH           A
# 202430  118033522          IF        REP     BRANDT    JASMINE           A
# 202431  118033522          IF        REP     BRANDT    JASMINE           A
# 202432  118033522          IF        REP     BRANDT    JASMINE           A
# 202433  118033522          IF        REP     BRANDT    JASMINE           A
# 202434  118033522          IF        REP     BRANDT    JASMINE           A
# 202435  118033522          IF        REP     BRANDT    JASMINE           A
# 202436  118033522          IF        REP     BRANDT    JASMINE           A
# 202437  118033522          IF        REP     BRANDT    JASMINE           A
# 202438  118016054          IF        REP     BRANDT    SHANNON           J
# 202439  118033523          IF        REP     BRANDT     WALTER           J
# 202440  118033523          IF        REP     BRANDT     WALTER           J
# 202441  118033523          IF        REP     BRANDT     WALTER           J
# 202442  118033523          IF        REP     BRANDT     WALTER           J
# 202443  118033523          IF        REP     BRANDT     WALTER           J
# 202444  118033523          IF        REP     BRANDT     WALTER           J
# 202445  118033523          IF        REP     BRANDT     WALTER           J
# 202458  150698114          IF        UNA  BRENTNELL      ANITA           M
# 202459  150698114          IF        UNA  BRENTNELL      ANITA           M
# 202460  150698114          IF        UNA  BRENTNELL      ANITA           M
# 202702  118075190           A        DEM    CAPPARD      MOSES           S
# 202703  118075190           A        DEM    CAPPARD      MOSES           S
# 202704  118075190           A        DEM    CAPPARD      MOSES           S
# 202705  118075190           A        DEM    CAPPARD      MOSES           S
# 202706  118075190           A        DEM    CAPPARD      MOSES           S
# 202707  118075190           A        DEM    CAPPARD      MOSES           S
# ...           ...         ...        ...        ...        ...         ...
# 226953  150366319           A        REP      WYKER     EDWARD           L
# 226954  150366319           A        REP      WYKER     EDWARD           L
# 226955  150366319           A        REP      WYKER     EDWARD           L
# 226956  150366319           A        REP      WYKER     EDWARD           L
# 226957  150366319           A        REP      WYKER     EDWARD           L
# 226958  150679135           A        UNA      WYKER    JESSICA           L
# 226959  150679135           A        UNA      WYKER    JESSICA           L
# 226960  150679135           A        UNA      WYKER    JESSICA           L
# 226961  118061995           A        UNA      WYKER    TERESEA         NaN
# 226962  118061995           A        UNA      WYKER    TERESEA         NaN
# 226963  118061995           A        UNA      WYKER    TERESEA         NaN
# 226964  118061995           A        UNA      WYKER    TERESEA         NaN
# 226965  118061995           A        UNA      WYKER    TERESEA         NaN
# 226971  524926241           A        DEM      YANES      EDGAR         NaN
# 226974  118047565           A        REP    YARWOOD    BARBARA         NaN
# 226975  118047565           A        REP    YARWOOD    BARBARA         NaN
# 226976  118047565           A        REP    YARWOOD    BARBARA         NaN
# 226977  118047565           A        REP    YARWOOD    BARBARA         NaN
# 226978  118047565           A        REP    YARWOOD    BARBARA         NaN
# 226979  118047565           A        REP    YARWOOD    BARBARA         NaN
# 226980  118047565           A        REP    YARWOOD    BARBARA         NaN
# 226981  118047565           A        REP    YARWOOD    BARBARA         NaN
# 226982  118047565           A        REP    YARWOOD    BARBARA         NaN
# 226983  118047565           A        REP    YARWOOD    BARBARA         NaN
# 226984  118047565           A        REP    YARWOOD    BARBARA         NaN
# 226985  118047565           A        REP    YARWOOD    BARBARA         NaN
# 226986  118047565           A        REP    YARWOOD    BARBARA         NaN
# 226987  118047565           A        REP    YARWOOD    BARBARA         NaN
# 226988  118047565           A        REP    YARWOOD    BARBARA         NaN
# 226989  118047565           A        REP    YARWOOD    BARBARA         NaN
#
#        prefix suffix sex street number suffix a suffix b street name  \
# 202350    NaN    NaN   F            25      NaN      NaN    WATER ST
# 202351    NaN    NaN   F            25      NaN      NaN    WATER ST
# 202352    NaN    NaN   F            25      NaN      NaN    WATER ST
# 202353    NaN    NaN   F            25      NaN      NaN    WATER ST
# 202354    NaN    NaN   F            25      NaN      NaN    WATER ST
# 202430    NaN    NaN   F             3      NaN      NaN    WATER ST
# 202431    NaN    NaN   F             3      NaN      NaN    WATER ST
# 202432    NaN    NaN   F             3      NaN      NaN    WATER ST
# 202433    NaN    NaN   F             3      NaN      NaN    WATER ST
# 202434    NaN    NaN   F             3      NaN      NaN    WATER ST
# 202435    NaN    NaN   F             3      NaN      NaN    WATER ST
# 202436    NaN    NaN   F             3      NaN      NaN    WATER ST
# 202437    NaN    NaN   F             3      NaN      NaN    WATER ST
# 202438    NaN    NaN   N             3      NaN      NaN         NaN
# 202439    NaN    NaN   M             3      NaN      NaN    WATER ST
# 202440    NaN    NaN   M             3      NaN      NaN    WATER ST
# 202441    NaN    NaN   M             3      NaN      NaN    WATER ST
# 202442    NaN    NaN   M             3      NaN      NaN    WATER ST
# 202443    NaN    NaN   M             3      NaN      NaN    WATER ST
# 202444    NaN    NaN   M             3      NaN      NaN    WATER ST
# 202445    NaN    NaN   M             3      NaN      NaN    WATER ST
# 202458    NaN    NaN   M            31        A      NaN    WATER ST
# 202459    NaN    NaN   M            31        A      NaN    WATER ST
# 202460    NaN    NaN   M            31        A      NaN    WATER ST
# 202702    NaN    NaN   N            27      NaN      NaN    WATER ST
# 202703    NaN    NaN   N            27      NaN      NaN    WATER ST
# 202704    NaN    NaN   N            27      NaN      NaN    WATER ST
# 202705    NaN    NaN   N            27      NaN      NaN    WATER ST
# 202706    NaN    NaN   N            27      NaN      NaN    WATER ST
# 202707    NaN    NaN   N            27      NaN      NaN    WATER ST
# ...       ...    ...  ..           ...      ...      ...         ...
# 226953    NaN    Jr.   F           238      NaN      NaN       RT 46
# 226954    NaN    Jr.   F           238      NaN      NaN       RT 46
# 226955    NaN    Jr.   F           238      NaN      NaN       RT 46
# 226956    NaN    Jr.   F           238      NaN      NaN       RT 46
# 226957    NaN    Jr.   F           238      NaN      NaN       RT 46
# 226958    NaN    NaN   F           238      NaN      NaN       RT 46
# 226959    NaN    NaN   F           238      NaN      NaN       RT 46
# 226960    NaN    NaN   F           238      NaN      NaN       RT 46
# 226961    NaN    NaN   F           238      NaN      NaN       RT 46
# 226962    NaN    NaN   F           238      NaN      NaN       RT 46
# 226963    NaN    NaN   F           238      NaN      NaN       RT 46
# 226964    NaN    NaN   F           238      NaN      NaN       RT 46
# 226965    NaN    NaN   F           238      NaN      NaN       RT 46
# 226971    NaN    NaN   N           220      NaN      NaN         NaN
# 226974    NaN    NaN   F           241      NaN      NaN       RT 46
# 226975    NaN    NaN   F           241      NaN      NaN       RT 46
# 226976    NaN    NaN   F           241      NaN      NaN       RT 46
# 226977    NaN    NaN   F           241      NaN      NaN       RT 46
# 226978    NaN    NaN   F           241      NaN      NaN       RT 46
# 226979    NaN    NaN   F           241      NaN      NaN       RT 46
# 226980    NaN    NaN   F           241      NaN      NaN       RT 46
# 226981    NaN    NaN   F           241      NaN      NaN       RT 46
# 226982    NaN    NaN   F           241      NaN      NaN       RT 46
# 226983    NaN    NaN   F           241      NaN      NaN       RT 46
# 226984    NaN    NaN   F           241      NaN      NaN       RT 46
# 226985    NaN    NaN   F           241      NaN      NaN       RT 46
# 226986    NaN    NaN   F           241      NaN      NaN       RT 46
# 226987    NaN    NaN   F           241      NaN      NaN       RT 46
# 226988    NaN    NaN   F           241      NaN      NaN       RT 46
# 226989    NaN    NaN   F           241      NaN      NaN       RT 46
#
#        apt/unit no. address line 1 address line 2    city state   zip5 zip4  \
# 202350          NaN     PO BOX 412            NaN  vienna    NJ  07880  NaN
# 202351          NaN     PO BOX 412            NaN  vienna    NJ  07880  NaN
# 202352          NaN     PO BOX 412            NaN  vienna    NJ  07880  NaN
# 202353          NaN     PO BOX 412            NaN  vienna    NJ  07880  NaN
# 202354          NaN     PO BOX 412            NaN  vienna    NJ  07880  NaN
# 202430          NaN            NaN            NaN  vienna    NJ  07880  NaN
# 202431          NaN            NaN            NaN  vienna    NJ  07880  NaN
# 202432          NaN            NaN            NaN  vienna    NJ  07880  NaN
# 202433          NaN            NaN            NaN  vienna    NJ  07880  NaN
# 202434          NaN            NaN            NaN  vienna    NJ  07880  NaN
# 202435          NaN            NaN            NaN  vienna    NJ  07880  NaN
# 202436          NaN            NaN            NaN  vienna    NJ  07880  NaN
# 202437          NaN            NaN            NaN  vienna    NJ  07880  NaN
# 202438     WATER ST            NaN            NaN  vienna    NJ  07880  NaN
# 202439          NaN            NaN            NaN  vienna    NJ  07880  NaN
# 202440          NaN            NaN            NaN  vienna    NJ  07880  NaN
# 202441          NaN            NaN            NaN  vienna    NJ  07880  NaN
# 202442          NaN            NaN            NaN  vienna    NJ  07880  NaN
# 202443          NaN            NaN            NaN  vienna    NJ  07880  NaN
# 202444          NaN            NaN            NaN  vienna    NJ  07880  NaN
# 202445          NaN            NaN            NaN  vienna    NJ  07880  NaN
# 202458            B            NaN            NaN  vienna    NJ  07880  NaN
# 202459            B            NaN            NaN  vienna    NJ  07880  NaN
# 202460            B            NaN            NaN  vienna    NJ  07880  NaN
# 202702          NaN            NaN            NaN  vienna    NJ  07880  NaN
# 202703          NaN            NaN            NaN  vienna    NJ  07880  NaN
# 202704          NaN            NaN            NaN  vienna    NJ  07880  NaN
# 202705          NaN            NaN            NaN  vienna    NJ  07880  NaN
# 202706          NaN            NaN            NaN  vienna    NJ  07880  NaN
# 202707          NaN            NaN            NaN  vienna    NJ  07880  NaN
# ...             ...            ...            ...     ...   ...    ...  ...
# 226953          NaN            NaN            NaN  vienna    NJ  07880  NaN
# 226954          NaN            NaN            NaN  vienna    NJ  07880  NaN
# 226955          NaN            NaN            NaN  vienna    NJ  07880  NaN
# 226956          NaN            NaN            NaN  vienna    NJ  07880  NaN
# 226957          NaN            NaN            NaN  vienna    NJ  07880  NaN
# 226958          NaN     PO BOX 366            NaN  vienna    NJ  07880  NaN
# 226959          NaN     PO BOX 366            NaN  vienna    NJ  07880  NaN
# 226960          NaN     PO BOX 366            NaN  vienna    NJ  07880  NaN
# 226961          NaN            NaN            NaN  vienna    NJ  07880  NaN
# 226962          NaN            NaN            NaN  vienna    NJ  07880  NaN
# 226963          NaN            NaN            NaN  vienna    NJ  07880  NaN
# 226964          NaN            NaN            NaN  vienna    NJ  07880  NaN
# 226965          NaN            NaN            NaN  vienna    NJ  07880  NaN
# 226971        RT 46            NaN            NaN  vienna    NJ  07880  NaN
# 226974          NaN            NaN            NaN  vienna    NJ  07880  NaN
# 226975          NaN            NaN            NaN  vienna    NJ  07880  NaN
# 226976          NaN            NaN            NaN  vienna    NJ  07880  NaN
# 226977          NaN            NaN            NaN  vienna    NJ  07880  NaN
# 226978          NaN            NaN            NaN  vienna    NJ  07880  NaN
# 226979          NaN            NaN            NaN  vienna    NJ  07880  NaN
# 226980          NaN            NaN            NaN  vienna    NJ  07880  NaN
# 226981          NaN            NaN            NaN  vienna    NJ  07880  NaN
# 226982          NaN            NaN            NaN  vienna    NJ  07880  NaN
# 226983          NaN            NaN            NaN  vienna    NJ  07880  NaN
# 226984          NaN            NaN            NaN  vienna    NJ  07880  NaN
# 226985          NaN            NaN            NaN  vienna    NJ  07880  NaN
# 226986          NaN            NaN            NaN  vienna    NJ  07880  NaN
# 226987          NaN            NaN            NaN  vienna    NJ  07880  NaN
# 226988          NaN            NaN            NaN  vienna    NJ  07880  NaN
# 226989          NaN            NaN            NaN  vienna    NJ  07880  NaN
#
#        mailing street number mailing suffix a  mailing suffix b  \
# 202350                   NaN              NaN               NaN
# 202351                   NaN              NaN               NaN
# 202352                   NaN              NaN               NaN
# 202353                   NaN              NaN               NaN
# 202707                    NaN       VIENNA            NJ   UNITED STATES
# ...                       ...          ...           ...             ...
# 226953                    NaN       VIENNA            NJ   UNITED STATES
# 226954                    NaN       VIENNA            NJ   UNITED STATES
# 226955                    NaN       VIENNA            NJ   UNITED STATES
# 226956                    NaN       VIENNA            NJ   UNITED STATES
# 226957                    NaN       VIENNA            NJ   UNITED STATES
# 226958                    NaN          NaN           NaN             NaN
# 226959                    NaN          NaN           NaN             NaN
# 226960                    NaN          NaN           NaN             NaN
# 226961                    NaN       VIENNA            NJ             NaN
# 226962                    NaN       VIENNA            NJ             NaN
# 226963                    NaN       VIENNA            NJ             NaN
# 226964                    NaN       VIENNA            NJ             NaN
# 226965                    NaN       VIENNA            NJ             NaN
# 226971                    NaN       VIENNA            NJ   UNITED STATES
# 226974                    NaN       VIENNA            NJ             NaN
# 226975                    NaN       VIENNA            NJ             NaN
# 226976                    NaN       VIENNA            NJ             NaN
# 226977                    NaN       VIENNA            NJ             NaN
# 226978                    NaN       VIENNA            NJ             NaN
# 226979                    NaN       VIENNA            NJ             NaN
# 226980                    NaN       VIENNA            NJ             NaN
# 226981                    NaN       VIENNA            NJ             NaN
# 226982                    NaN       VIENNA            NJ             NaN
# 226983                    NaN       VIENNA            NJ             NaN
# 226984                    NaN       VIENNA            NJ             NaN
# 226985                    NaN       VIENNA            NJ             NaN
# 226986                    NaN       VIENNA            NJ             NaN
# 226987                    NaN       VIENNA            NJ             NaN
# 226988                    NaN       VIENNA            NJ             NaN
# 226989                    NaN       VIENNA            NJ             NaN
#
#        mailing zip code  birth date date registered county precinct  \
# 202350              NaN  08/20/1960      05/28/2004        11800115
# 202351              NaN  08/20/1960      05/28/2004        11800115
# 202352              NaN  08/20/1960      05/28/2004        11800115
# 202353              NaN  08/20/1960      05/28/2004        11800115
# 202354              NaN  08/20/1960      05/28/2004        11800115
# 202430            07880  07/10/1951      09/08/1992        11800115
# 202431            07880  07/10/1951      09/08/1992        11800115
# 202432            07880  07/10/1951      09/08/1992        11800115
# 202433            07880  07/10/1951      09/08/1992        11800115
# 202434            07880  07/10/1951      09/08/1992        11800115
# 202435            07880  07/10/1951      09/08/1992        11800115
# 202436            07880  07/10/1951      09/08/1992        11800115
# 202437            07880  07/10/1951      09/08/1992        11800115
# 202438            07880  09/02/1977      09/20/2000        11800115
# 202439            07880  10/25/1948      09/08/1992        11800115
# 202440            07880  10/25/1948      09/08/1992        11800115
# 202441            07880  10/25/1948      09/08/1992        11800115
# 202442            07880  10/25/1948      09/08/1992        11800115
# 202443            07880  10/25/1948      09/08/1992        11800115
# 202444            07880  10/25/1948      09/08/1992        11800115
# 202445            07880  10/25/1948      09/08/1992        11800115
# 202458              NaN  02/27/1958      09/22/2008        11800115
# 202459              NaN  02/27/1958      09/22/2008        11800115
# 202460              NaN  02/27/1958      09/22/2008        11800115
# 202702            07880  03/30/1955      05/10/2004        11800115
# 202703            07880  03/30/1955      05/10/2004        11800115
# 202704            07880  03/30/1955      05/10/2004        11800115
# 202705            07880  03/30/1955      05/10/2004        11800115
# 202706            07880  03/30/1955      05/10/2004        11800115
# 202459  INDEPENDENCE   0.0       1.0          NaN    11/04/2008
# 202460  INDEPENDENCE   0.0       1.0          NaN    11/08/2016
# 202702  INDEPENDENCE   0.0       1.0          908    06/05/2007
# 202703  INDEPENDENCE   0.0       1.0          908    11/06/2007
# 202704  INDEPENDENCE   0.0       1.0          908    11/08/2011
# 202705  INDEPENDENCE   0.0       1.0          908    11/02/2010
# 202706  INDEPENDENCE   0.0       1.0          908    11/03/2009
# 202707  INDEPENDENCE   0.0       1.0          908    02/05/2008
# ...              ...   ...       ...          ...           ...
# 226953  INDEPENDENCE   0.0       4.0          NaN    11/05/2013
# 226954  INDEPENDENCE   0.0       4.0          NaN    06/03/2014
# 226955  INDEPENDENCE   0.0       4.0          NaN    11/04/2014
# 226956  INDEPENDENCE   0.0       4.0          NaN    11/03/2015
# 226957  INDEPENDENCE   0.0       4.0          NaN    11/08/2016
# 226958  INDEPENDENCE   0.0       4.0          NaN    11/04/2008
# 226959  INDEPENDENCE   0.0       4.0          NaN    11/06/2012
# 226960  INDEPENDENCE   0.0       4.0          NaN    11/08/2016
# 226961  INDEPENDENCE   0.0       4.0          NaN    04/20/2010
# 226962  INDEPENDENCE   0.0       4.0          NaN    11/03/2009
# 226963  INDEPENDENCE   0.0       4.0          NaN    11/04/2008
# 226964  INDEPENDENCE   0.0       4.0          NaN    11/06/2012
# 226965  INDEPENDENCE   0.0       4.0          NaN    11/08/2016
# 226971  INDEPENDENCE   0.0       4.0          NaN           NaN
# 226974  INDEPENDENCE   0.0       4.0          NaN    06/05/2007
# 226975  INDEPENDENCE   0.0       4.0          NaN    11/06/2007
# 226976  INDEPENDENCE   0.0       4.0          NaN    04/20/2010
# 226977  INDEPENDENCE   0.0       4.0          NaN    11/02/2010
# 226978  INDEPENDENCE   0.0       4.0          NaN    04/21/2009
# 226979  INDEPENDENCE   0.0       4.0          NaN    11/03/2009
# 226980  INDEPENDENCE   0.0       4.0          NaN    02/05/2008
# 226981  INDEPENDENCE   0.0       4.0          NaN    06/03/2008
# 226982  INDEPENDENCE   0.0       4.0          NaN    11/04/2008
# 226983  INDEPENDENCE   0.0       4.0          NaN    11/06/2012
# 226984  INDEPENDENCE   0.0       4.0          NaN    06/04/2013
# 226985  INDEPENDENCE   0.0       4.0          NaN    11/05/2013
# 226986  INDEPENDENCE   0.0       4.0          NaN    11/04/2014
# 226987  INDEPENDENCE   0.0       4.0          NaN    11/03/2015
# 226988  INDEPENDENCE   0.0       4.0          NaN    06/07/2016
# 226989  INDEPENDENCE   0.0       4.0          NaN    11/08/2016
#
#                  election name election type election category ballot type  xx
# 202350  STATE GENERAL ELECTION           GEN                 S           M NaN
# 202351        GENERAL ELECTION           GEN                 S           M NaN
# 202352        GENERAL ELECTION           GEN                 S           M NaN
# 202353        GENERAL ELECTION           GEN                 S           M NaN
# 202354        GENERAL ELECTION           GEN                 S           M NaN
# 202430   STATE SCHOOL ELECTION           ANS                 S           M NaN
# 202431      STATE PRIMARY 2010           PRI                 S           M NaN
# 202432  STATE PRIMARY ELECTION           PRI                 S           M NaN
